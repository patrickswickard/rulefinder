# %%
import csv 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import numpy as np 
import pandas as pd 
         
# %reload_ext autoreload 
# %autoreload 2

# %%
########################
with open("Open_Checkbook_FY2021_Dataset.csv",'r') as budget_file:
  #reader = csv.reader(budget_file)
  df = pd.read_csv(budget_file)


#print('hi')
#print(df)
print(df.index)
print(df.columns)


unique_values_per_column = {}
for thiscolname in df.columns:
# print(thiscolname)
  tcvc = df[thiscolname].value_counts('')
  print(type(tcvc))    
# print(str(len(df[thiscolname].value_counts(''))) + ' unique values')
# print(str(len(tcvc)) + ' unique values')
  print(tcvc.index)
  print(tcvc)
  print('****************')
# Out:
# RangeIndex(start=0, stop=99296, step=1)
# Index(['OBJECTID_1', 'OBJECTID', 'Date', 'Agency', 'Service',
#        'Spending_Category', 'Spending_Description', 'Fund', 'Amount',
#        'Vendor_Name', 'Date_Accuracy', 'name', 'GlobalID'],
#       dtype='object')
# <class 'pandas.core.series.Series'>
# Index([    1, 66230, 66204, 66203, 66202, 66201, 66200, 66199, 66198, 66197,
#        ...
#        33102, 33101, 33100, 33099, 33098, 33097, 33096, 33095, 33094, 99296],
#       dtype='int64', name='OBJECTID_1', length=99296)
# OBJECTID_1
# 1        1
# 66230    1
# 66204    1
# 66203    1
# 66202    1
#         ..
# 33097    1
# 33096    1
# 33095    1
# 33094    1
# 99296    1
# Name: count, Length: 99296, dtype: int64
# ****************
# <class 'pandas.core.series.Series'>
# Index([  201, 66146, 66120, 66119, 66118, 66117, 66116, 66115, 66114, 66113,
#        ...
#        32972, 32813, 33067, 32971, 32970, 32969, 32968, 32812, 33200, 99296],
# ...

# %%
print(df.groupby('Agency').count())
# Out:
#                                            OBJECTID_1  OBJECTID   Date  \
# Agency
# Board of Elections                                229       229    229
# City Council                                      158       158    158
# City Council Services                              44        44     44
# Comptroller                                       786       786    786
# Courts - Circuit Court                            781       781    781
# Courts - Orphans' Court                            16        16     16
# Employees' Retirement Systems                     117       117    117
# Enoch Pratt Free Library                         1949      1949   1949
# Finance                                          2001      2001   2001
# Fire                                             8797      8797   8797
# General Services                                11850     11850  11850
# Health                                           5937      5937   5937
# ...

# %%
df2 = pd.DataFrame({'Animal': ['Falcon', 'Falcon',

                              'Parrot', 'Parrot'],

                   'Max Speed': [380., 370., 24., 24.]})
print(df2)

print(df2.groupby('Animal').nunique())
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       24.0
#         Max Speed
# Animal
# Falcon          2
# Parrot          1
